# %% [markdown]
# # Instruments

# %%
import os
import sys

import numpy as np
import pandas as pd

sys.path.insert(0, os.path.join(".."))

# %% [markdown]
# ## Meudon PDR code predictions

# %%
from infobs.model import MeudonPDR

meudonpdr = MeudonPDR()

df_params = pd.DataFrame({
    "Av": [1, 5, 10, 15, 20],
    "G0": [1e2, 1e2, 1e2, 1e2, 1e2],
    "Pth": [1e5, 1e5, 1e5, 1e5, 1e5],
    "angle": [0, 0, 0, 0, 0]
})

df_params
# Out:
#    Av     G0       Pth  angle
# 0   1  100.0  100000.0      0
# 1   5  100.0  100000.0      0
# 2  10  100.0  100000.0      0
# 3  15  100.0  100000.0      0
# 4  20  100.0  100000.0      0

# %%
meudonpdr.predict(
    df_params
)
# Out:
#      Av     G0       Pth  angle  kappa  h2_v0_j2__v0_j0  h2_v0_j3__v0_j1  \
# 0   1.0  100.0  100000.0    0.0    1.0         0.010243         0.002992
# 1   5.0  100.0  100000.0    0.0    1.0         0.009836         0.003158
# 2  10.0  100.0  100000.0    0.0    1.0         0.010026         0.003207
# 3  15.0  100.0  100000.0    0.0    1.0         0.010062         0.003317
# 4  20.0  100.0  100000.0    0.0    1.0         0.010102         0.003278
#
#    h2_v0_j4__v0_j2  h2_v0_j5__v0_j3  h2_v0_j6__v0_j4  ...  \
# 0         0.000057         0.000010         0.000002  ...
# 1         0.000060         0.000010         0.000002  ...
# 2         0.000059         0.000010         0.000002  ...
# 3         0.000059         0.000010         0.000002  ...
# 4         0.000058         0.000011         0.000002  ...
#
#    shp_n10_j11_f11d5__n9_j10_f10d5  shp_n10_j10_f10d5__n9_j9_f9d5  \
# 0                     2.991196e-12                   2.645448e-12
# 1                     2.927281e-12                   2.588342e-12
# 2                     2.915170e-12                   2.580306e-12
# 3                     2.913692e-12                   2.583992e-12
# 4                     2.893779e-12                   2.571290e-12
#
#    shp_n10_j9_f9d5__n9_j8_f8d5  shp_n10_j9_f9d5__n9_j10_f10d5  \
# 0                 2.420507e-12                   3.334513e-17
# 1                 2.376320e-12                   3.258995e-17
# 2                 2.359131e-12                   3.258680e-17
# 3                 2.372837e-12                   3.241424e-17
# 4                 2.359847e-12                   3.224938e-17
#
#    shp_n10_j10_f10d5__n9_j10_f10d5  shp_n5_j4_f4d5__n2_j3_f3d5  \
# 0                     2.685572e-14                7.130854e-14
# 1                     2.626043e-14                7.143769e-14
# 2                     2.623749e-14                7.176126e-14
# 3                     2.622504e-14                7.204642e-14
# 4                     2.617005e-14                7.181391e-14
#
#    shp_n6_j5_f5d5__n3_j4_f4d5  shp_n7_j6_f6d5__n4_j5_f5d5  \
# 0                1.255194e-14                2.563640e-15
# 1                1.253789e-14                2.521841e-15
# 2                1.255073e-14                2.530706e-15
# 3                1.255310e-14                2.542738e-15
# 4                1.253679e-14                2.545107e-15
#
#    shp_n8_j7_f7d5__n5_j6_f6d5  shp_n9_j8_f8d5__n6_j7_f7d5
# 0                5.562906e-16                1.247624e-16
# 1                5.556850e-16                1.238246e-16
# 2                5.523370e-16                1.229295e-16
# 3                5.539160e-16                1.230413e-16
# 4                5.531721e-16                1.225758e-16
#
# [5 rows x 5025 columns]

# %%
df = meudonpdr.predict(
    df_params,
    lines=["13c_o_j1__j0", "13c_o_j2__j1", "13c_o_j3__j2", "c_el3p_j1__el3p_j0", "c_el3p_j2__el3p_j1", "cp_el2p_j3_2__el2p_j1_2"]
)

df
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0      0.000276      0.000318
# 1   5.0  100.0  100000.0    0.0    1.0     10.176692     11.708745
# 2  10.0  100.0  100000.0    0.0    1.0     22.873276     21.915024
# 3  15.0  100.0  100000.0    0.0    1.0     29.498773     25.964494
# 4  20.0  100.0  100000.0    0.0    1.0     34.912525     29.605632
#
#    13c_o_j3__j2  c_el3p_j1__el3p_j0  c_el3p_j2__el3p_j1  \
# 0      0.000128            0.237290            0.168541
# 1      3.919423           22.388675           11.729995
# 2      8.102161           21.884921           11.508051
# 3     10.321277           22.693579           11.846299
# 4     12.635616           23.212814           12.121948
#
#    cp_el2p_j3_2__el2p_j1_2
# 0                 7.993103
# 1                10.794163
# 2                10.750909
# 3                10.839103
# 4                10.800269

# %% [markdown]
# ## Instruments

# %%
obstime = 1 # Minutes
linewidth = 10 # km/s

# %% [markdown]
# ### Ideal instrument
#
# **Note:** By definition, the integration time `obstime` has no effect when using the ideal instrument.

# %%
from infobs.instruments import IdealInstrument

ideal = IdealInstrument()

ideal.measure(
    df, obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0      0.000276      0.000318
# 1   5.0  100.0  100000.0    0.0    1.0     10.176692     11.708745
# 2  10.0  100.0  100000.0    0.0    1.0     22.873276     21.915024
# 3  15.0  100.0  100000.0    0.0    1.0     29.498773     25.964494
# 4  20.0  100.0  100000.0    0.0    1.0     34.912525     29.605632
#
#    13c_o_j3__j2  c_el3p_j1__el3p_j0  c_el3p_j2__el3p_j1  \
# 0      0.000128            0.237290            0.168541
# 1      3.919423           22.388675           11.729995
# 2      8.102161           21.884921           11.508051
# 3     10.321277           22.693579           11.846299
# 4     12.635616           23.212814           12.121948
#
#    cp_el2p_j3_2__el2p_j1_2
# 0                 7.993103
# 1                10.794163
# 2                10.750909
# 3                10.839103
# 4                10.800269

# %% [markdown]
# ### IRAM 30m EMIR

# %%
from infobs.instruments import IRAM30mEMIR

emir = IRAM30mEMIR(linewidth)

emir.measure(
    emir.filter_lines(df), obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0      2.304100      1.186082
# 1   5.0  100.0  100000.0    0.0    1.0     11.045154     12.614035
# 2  10.0  100.0  100000.0    0.0    1.0     21.275261     20.809291
# 3  15.0  100.0  100000.0    0.0    1.0     30.982845     27.994013
# 4  20.0  100.0  100000.0    0.0    1.0     34.579477     24.472355
#
#    13c_o_j3__j2
# 0      2.559229
# 1      7.962028
# 2     12.215755
# 3     21.121263
# 4      8.870162

# %% [markdown]
# #### Changing integration time

# %%
emir.measure(
    emir.filter_lines(df), 10*obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0      1.007058     -0.061244
# 1   5.0  100.0  100000.0    0.0    1.0     10.733919     11.054353
# 2  10.0  100.0  100000.0    0.0    1.0     22.532765     20.564771
# 3  15.0  100.0  100000.0    0.0    1.0     27.842653     29.493280
# 4  20.0  100.0  100000.0    0.0    1.0     31.244859     32.500944
#
#    13c_o_j3__j2
# 0     -0.406238
# 1      1.201543
# 2      9.082299
# 3      8.562712
# 4     11.883908

# %% [markdown]
# #### Changing line width
#
# `linewidth` mandatory argument.

# %%
emir = IRAM30mEMIR(linewidth=2*linewidth)

emir.measure(
    emir.filter_lines(df), obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0     -5.599257      0.029949
# 1   5.0  100.0  100000.0    0.0    1.0      8.376963     15.003082
# 2  10.0  100.0  100000.0    0.0    1.0     17.128225     18.203982
# 3  15.0  100.0  100000.0    0.0    1.0     29.142781     33.710153
# 4  20.0  100.0  100000.0    0.0    1.0     35.617939     34.560992
#
#    13c_o_j3__j2
# 0      6.860503
# 1      9.801187
# 2      3.208072
# 3     14.633763
# 4     -0.637018

# %% [markdown]
# #### Integrated precipitable water vapor
#
# `ipwv` optional argument.
# * Available values: 0 (excellent conditions), 1 (good conditions), 2 (normal conditions)
# * Default: 2

# %%
emir = IRAM30mEMIR(linewidth, ipwv=0)

emir.measure(
    emir.filter_lines(df), obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0      3.637652     -0.302471
# 1   5.0  100.0  100000.0    0.0    1.0     13.113089     11.641636
# 2  10.0  100.0  100000.0    0.0    1.0     23.734262     27.891698
# 3  15.0  100.0  100000.0    0.0    1.0     27.723701     27.294525
# 4  20.0  100.0  100000.0    0.0    1.0     31.520066     29.115825
#
#    13c_o_j3__j2
# 0      1.208588
# 1     -1.319127
# 2      8.298691
# 3     13.622968
# 4     14.508134

# %% [markdown]
# ## Implementing other instruments

# %%
from infobs.instruments import StandardInstrument

# %% [markdown]
# ### Mount Fuji submillimeter-wave telescope for [CI] lines

# %%
class Fuji(StandardInstrument):
    """
    Obstime must be interpreted as a relative integration time compared with the one achieved in T. Oka et al, 2004 (ApJ).
    For simplicity sake, we assume the noise RMS to be identical for both lines.
    """

    def __init__(
        self,
        linewidth: float,
        kelvin: bool=True
    ):
        super().__init__(
            ["c_el3p_j1__el3p_j0", "c_el3p_j2__el3p_j1"],
            kelvin
        )

    @property
    def dv(self):
        return 1.0 # km/s

    @property
    def ref_obstime(self):
        return {
            "c_el3p_j1__el3p_j0": 1,
            "c_el3p_j2__el3p_j1": 1
        }

    @property
    def rms(self):
        return {
            "c_el3p_j1__el3p_j0": 0.5,
            "c_el3p_j2__el3p_j1": 0.5
        }
        
    @property
    def percent(self):
        return {
            "c_el3p_j1__el3p_j0": 20,
            "c_el3p_j2__el3p_j1": 20
        }

    def __str__(self):
        return "Mount Fuji telescope"

# %%
fuji = Fuji(linewidth)
fuji_obstime = 0.5

fuji.measure(
    fuji.filter_lines(df), fuji_obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  c_el3p_j1__el3p_j0  c_el3p_j2__el3p_j1
# 0   1.0  100.0  100000.0    0.0    1.0           -0.353822           -0.180102
# 1   5.0  100.0  100000.0    0.0    1.0           26.541506           10.524991
# 2  10.0  100.0  100000.0    0.0    1.0           18.180540            7.015612
# 3  15.0  100.0  100000.0    0.0    1.0           16.307703           11.164658
# 4  20.0  100.0  100000.0    0.0    1.0           27.354132           10.895989

# %% [markdown]
# ### SOFIA (Stratospheric Observatory for Infrared Astronomy) for [CII] line

# %%
class SOFIA(StandardInstrument):
    """
    Obstime must be interpreted as a relative integration time compared with the one achieved in Pabst et al, 2017 (A&A).
    Calibration error is discussed in Risacher et al, 2016.
    """

    def __init__(
        self,
        linewidth: float,
        kelvin: bool=True
    ):
        super().__init__(
            ["cp_el2p_j3_2__el2p_j1_2"],
            kelvin
        )

    @property
    def dv(self):
        return 0.193 # km/s

    @property
    def ref_obstime(self):
        return {
            "cp_el2p_j3_2__el2p_j1_2": 1
        }

    @property
    def rms(self):
        return {
            "cp_el2p_j3_2__el2p_j1_2": 2.25
        }
        
    @property
    def percent(self):
        return {
            "cp_el2p_j3_2__el2p_j1_2": 5
        }

    def __str__(self):
        return "SOFIA"

# %%
sofia = SOFIA(linewidth)
sofia_obstime = 0.25

sofia.measure(
    sofia.filter_lines(df), fuji_obstime
)
# Out:
#      Av     G0       Pth  angle  kappa  cp_el2p_j3_2__el2p_j1_2
# 0   1.0  100.0  100000.0    0.0    1.0                 7.173556
# 1   5.0  100.0  100000.0    0.0    1.0                10.857059
# 2  10.0  100.0  100000.0    0.0    1.0                 8.986045
# 3  15.0  100.0  100000.0    0.0    1.0                12.189415
# 4  20.0  100.0  100000.0    0.0    1.0                11.791652

# %% [markdown]
# ### Mixing instruments

# %%
from infobs.instruments import MergedInstrument

merged = MergedInstrument(
    [emir, fuji, sofia]
)

# %%
merged.measure(
    merged.filter_lines(df),
    [obstime, fuji_obstime, sofia_obstime]
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0     -1.394607      1.790921
# 1   5.0  100.0  100000.0    0.0    1.0     10.271918      8.804715
# 2  10.0  100.0  100000.0    0.0    1.0     21.093096     20.478475
# 3  15.0  100.0  100000.0    0.0    1.0     29.499523     24.465393
# 4  20.0  100.0  100000.0    0.0    1.0     33.713076     35.565098
#
#    13c_o_j3__j2  c_el3p_j1__el3p_j0  c_el3p_j2__el3p_j1  \
# 0      1.990865            1.067935            0.169435
# 1      5.461707           20.382862           12.709262
# 2      8.369292           17.634216            9.516761
# 3      9.611141           22.491916            9.317297
# 4     13.903594           19.555128           12.418816
#
#    cp_el2p_j3_2__el2p_j1_2
# 0                 8.098664
# 1                10.241453
# 2                 8.793674
# 3                10.023532
# 4                 6.144656

# %% [markdown]
# You can use the same instrument with two different integration times with two instances of the same instrument using the `restrict_lines` method.
#
# In the following example, the second transition of [CI] is integrated 10 times longer.

# %%
fuji1 = Fuji(linewidth)
fuji1.restrict_lines(["c_el3p_j1__el3p_j0"])
fuji2 = Fuji(linewidth)
fuji2.restrict_lines(["c_el3p_j2__el3p_j1"])

merged = MergedInstrument(
    [emir, fuji1, fuji2, sofia]
)

merged.measure(
    merged.filter_lines(df),
    [obstime, fuji_obstime, 10*fuji_obstime, sofia_obstime]
)
# Out:
#      Av     G0       Pth  angle  kappa  13c_o_j1__j0  13c_o_j2__j1  \
# 0   1.0  100.0  100000.0    0.0    1.0      0.429596      1.290377
# 1   5.0  100.0  100000.0    0.0    1.0     11.208933     11.345129
# 2  10.0  100.0  100000.0    0.0    1.0     22.865378     19.874641
# 3  15.0  100.0  100000.0    0.0    1.0     25.463512     24.593912
# 4  20.0  100.0  100000.0    0.0    1.0     35.870254     32.683043
#
#    13c_o_j3__j2  c_el3p_j1__el3p_j0  c_el3p_j2__el3p_j1  \
# 0      3.208243           -0.546726           -0.145097
# 1     -2.303984           25.432893           14.693545
# 2      9.037263           24.292709           12.537440
# 3     12.059598           23.657297           18.576150
# 4     19.930144           29.086794           17.062069
#
#    cp_el2p_j3_2__el2p_j1_2
# 0                 9.386241
# 1                13.910911
# 2                11.606017
# 3                11.382027
# 4                11.930846

# %% [markdown]
# All these instruments can then be used to simulate observations (see `simulator.ipynb` example notebook).
